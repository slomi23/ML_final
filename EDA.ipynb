# %%
### Notebook for EDA bbb
import numpy as np
import pandas as pd
import os

# %%
# %run data_extraction_feature_engineering.ipynb
df_train_full, df_test_full = extract_data()
print(df_train_full.columns.tolist())
# Out:
# Loading data...
# Train shape: (421570, 5)
# Features shape: (8190, 12)
# Stores shape: (45, 3)
# Test shape: (115064, 4)
# Merging datasets...
#
# Data Preparation Complete!
# X_train shape: (397841, 24)
# X_val shape: (23729, 24)
#    IsHoliday  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      False        42.31       2.572        0.0        0.0        0.0
# 1       True        38.51       2.548        0.0        0.0        0.0
# 2      False        39.93       2.514        0.0        0.0        0.0
# 3      False        46.63       2.561        0.0        0.0        0.0
# 4      False        46.50       2.625        0.0        0.0        0.0
#
#    MarkDown4  MarkDown5         CPI  Unemployment  ...  sales_lag_52  \
# 0        0.0        0.0  211.096358         8.106  ...           NaN
# 1        0.0        0.0  211.242170         8.106  ...           NaN
# 2        0.0        0.0  211.289143         8.106  ...           NaN
# 3        0.0        0.0  211.319643         8.106  ...           NaN
# 4        0.0        0.0  211.350143         8.106  ...           NaN
#
#     roll_mean_4    roll_std_4   roll_mean_8  Year  Month  DayOfWeek  \
# 0           NaN           NaN           NaN  2010      2          4
# 1  24924.500000           NaN  24924.500000  2010      2          4
# 2  35481.995000  14930.552614  35481.995000  2010      2          4
# 3  37519.846667  11131.900957  37519.846667  2010      2          4
# 4  32990.770000  12832.106391  32990.770000  2010      3          4
#
#    WeekOfYear  Type_encoded  IsHoliday_int
# 0           5             1              0
# 1           6             1              1
# 2           7             1              0
# 3           8             1              0
# 4           9             1              0
#
# [5 rows x 24 columns] 0    24924.50
# 1    46039.49
# 2    41595.55
# 3    19403.54
# 4    21827.90
# Name: Weekly_Sales, dtype: float64
# Loading data...
# Train shape: (421570, 5)
# Features shape: (8190, 12)
# Stores shape: (45, 3)
# Test shape: (115064, 4)
# Merging datasets...
# ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'Type', 'Size']
